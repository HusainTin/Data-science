# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('House_Price.csv')
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
del df["bus_ter"]

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall     parks
# 0     River        23  0.049347
# 1      Lake        42  0.046146
# ...

# %%
df["River"]= False
df["Lake"] = False

# %%
df["waterbody"].unique()
# Out:
# array(['River', 'Lake', nan, 'Lake and River'], dtype=object)

# %%
df['Lake'] = df['waterbody'].str.contains('Lake', case=False)
df['River'] = df['waterbody'].str.contains('River', case=False)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall     parks  River   Lake
# 0     River        23  0.049347   True  False
# ...

# %%
df["Lake"] = df.Lake.fillna(False)
df["River"] = df.River.fillna(False)
# Out:
# /var/folders/mj/y2_4ydgn6_37x2f5dr6qw2780000gn/T/ipykernel_42633/4252896207.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Lake"] = df.Lake.fillna(False)
# /var/folders/mj/y2_4ydgn6_37x2f5dr6qw2780000gn/T/ipykernel_42633/4252896207.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["River"] = df.River.fillna(False)

# %%
del df["waterbody"]

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#    rainfall     parks  River   Lake
# 0        23  0.049347   True  False
# ...

# %%
df['airport'] = df['airport'].map({'YES': True, 'NO': False})

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     True       5.480      11.1920
# 1   5.12   5.06      22.2       9.14    False       7.332      12.1728
# 2   5.01   4.97      22.2       4.03    False       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     True       9.268      11.2672
# 4   6.37   5.86      21.3       5.33    False       8.824      11.2896
#
#    rainfall     parks  River   Lake
# 0        23  0.049347   True  False
# ...

# %%
df.corr()
# Out:
#                 price  crime_rate  resid_area  air_qual  room_num       age  \
# price        1.000000   -0.389582   -0.484754 -0.429300  0.696304 -0.377999
# crime_rate  -0.389582    1.000000    0.406583  0.420972 -0.219247  0.352734
# resid_area  -0.484754    0.406583    1.000000  0.763651 -0.391676  0.644779
# air_qual    -0.429300    0.420972    0.763651  1.000000 -0.302188  0.731470
# room_num     0.696304   -0.219247   -0.391676 -0.302188  1.000000 -0.240265
# age         -0.377999    0.352734    0.644779  0.731470 -0.240265  1.000000
# dist1        0.251355   -0.380050   -0.706481 -0.768589  0.208464 -0.746904
# dist2        0.249459   -0.379813   -0.707956 -0.769724  0.203981 -0.746493
# dist3        0.246650   -0.380069   -0.707566 -0.769157  0.201907 -0.747021
# dist4        0.248200   -0.376462   -0.705819 -0.764873  0.205397 -0.746707
# teachers     0.505655   -0.289946   -0.383248 -0.188933  0.355501 -0.261515
# ...

# %%
del df["parks"] # Deleted because of high correlation betweeen it and air_quality

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     True       5.480      11.1920
# 1   5.12   5.06      22.2       9.14    False       7.332      12.1728
# 2   5.01   4.97      22.2       4.03    False       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     True       9.268      11.2672
# 4   6.37   5.86      21.3       5.33    False       8.824      11.2896
#
#    rainfall  River   Lake
# 0        23   True  False
# 1        42  False   True
# ...

# %%
df["dist"] = round((df["dist1"] + df["dist2"] + df["dist3"] + df["dist4"])/4,2)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     True       5.480      11.1920
# 1   5.12   5.06      22.2       9.14    False       7.332      12.1728
# 2   5.01   4.97      22.2       4.03    False       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     True       9.268      11.2672
# 4   6.37   5.86      21.3       5.33    False       8.824      11.2896
#
#    rainfall  River   Lake  dist
# 0        23   True  False  4.09
# 1        42  False   True  4.97
# ...

# %%
del df["dist1"]

# %%
del df["dist2"]
del df["dist3"]
del df["dist4"]

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     0.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     0.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     0.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     0.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms  rainfall  River   Lake  dist
# 0       4.98     True       5.480      11.1920        23   True  False  4.09
# 1       9.14    False       7.332      12.1728        42  False   True  4.97
# 2       4.03    False       7.394     101.1200        38  False  False  4.97
# 3       2.94     True       9.268      11.2672        45  False   True  6.06
# 4       5.33    False       8.824      11.2896        55  False   True  6.06

# %%
import seaborn as sns 
sns.jointplot(x="n_hos_beds", y="n_hot_rooms", data=df)

# %%
sns.histplot(x="n_hot_rooms", data=df)
# Out:
# <Axes: xlabel='n_hot_rooms', ylabel='Count'>

# %%
df.n_hot_rooms.describe()
# Out:
# count    506.000000
# mean      13.041605
# std        5.238957
# min       10.057600
# 25%       11.189800
# 50%       12.720000
# 75%       14.170800
# max      101.120000
# Name: n_hot_rooms, dtype: float64

# %%
upper_limit = df.n_hot_rooms.quantile(0.99)

# %%
df = df[df['n_hot_rooms'] <= upper_limit]

# %%
sns.histplot(x="n_hot_rooms", data=df)
# Out:
# <Axes: xlabel='n_hot_rooms', ylabel='Count'>

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num        age  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.00000
# mean    22.303000    3.626173   41.131420    0.554731    6.271588   68.52160
# std      8.874781    8.646885    6.856656    0.116238    0.691202   28.20279
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.90000
# 25%     16.950000    0.082155   35.190000    0.449000    5.883000   44.85000
# 50%     21.150000    0.253715   39.690000    0.538000    6.198500   77.50000
# 75%     25.000000    3.674808   48.100000    0.624000    6.608500   94.02500
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.00000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms   rainfall        dist
# count  500.000000  500.000000  492.000000   500.000000  500.00000  500.000000
# mean    21.524200   12.714760    7.899435    12.710424   39.14200    3.805180
# ...

# %%
sns.histplot(x="crime_rate", data=df)
# Out:
# <Axes: xlabel='crime_rate', ylabel='Count'>

# %%
upper_limit = df.crime_rate.quantile(0.99)
df = df[df['crime_rate'] <= upper_limit]

# %%
sns.histplot(x="crime_rate", data=df)
# Out:
# <Axes: xlabel='crime_rate', ylabel='Count'>

# %%
df.count()
# Out:
# price          495
# crime_rate     495
# resid_area     495
# air_qual       495
# room_num       495
# age            495
# teachers       495
# poor_prop      495
# airport        495
# n_hos_beds     487
# n_hot_rooms    495
# rainfall       495
# River          495
# Lake           495
# dist           495
# dtype: int64

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  495.000000  495.000000  495.000000  495.000000  495.000000  495.000000
# mean    22.434949    3.001563   41.061030    0.553601    6.276586   68.220000
# std      8.814619    5.828109    6.855151    0.116220    0.688429   28.182034
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.150000    0.081930   35.160000    0.448500    5.886000   44.050000
# 50%     21.200000    0.249800   39.690000    0.538000    6.208000   76.900000
# 75%     25.000000    3.397665   48.100000    0.624000    6.611000   93.850000
# max     50.000000   41.529200   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall        dist
# count  495.000000  495.000000  487.000000   495.000000  495.000000  495.000000
# mean    21.541616   12.625212    7.896710    12.710793   39.127273    3.828040
# ...

# %%
upper_limit = df.crime_rate.quantile(0.98)
df = df[df['crime_rate'] <= upper_limit]

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  485.000000  485.000000  485.000000  485.000000  485.000000  485.000000
# mean    22.699588    2.460098   40.915897    0.550999    6.292571   67.698969
# std      8.695498    4.380798    6.849761    0.115900    0.682321   28.215823
# min      6.300000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.500000    0.079780   35.130000    0.448000    5.891000   42.800000
# 50%     21.400000    0.229270   38.560000    0.532000    6.211000   76.500000
# 75%     25.000000    2.449530   48.100000    0.624000    6.619000   93.600000
# max     50.000000   22.051100   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall        dist
# count  485.000000  485.000000  478.000000   485.000000  485.000000  485.000000
# mean    21.577526   12.370660    7.888377    12.694999   38.997938    3.874247
# ...

# %%
df.isna().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     7
# n_hot_rooms    0
# rainfall       0
# River          0
# Lake           0
# dist           0
# dtype: int64

# %%
df= df.dropna()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x = df.drop(["price"], axis=1)
y = df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2
)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.6915185732374054

# %%
model.score(X_train, y_train)
# Out:
# 0.7138664340756626
