# %%
import numpy as np
import time

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
# import tensorflow_hub as hub

import datetime

# %%
from tensorflow import keras   # Use this instead of tf.keras
import tensorflow_hub as hub

IMAGE_SHAPE = (224, 224)

# Use the legacy keras Sequential model
classifier = keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4", 
                   input_shape=IMAGE_SHAPE+(3,))
])
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 6
#       3 get_ipython().run_line_magic('pip', 'install --upgrade tensorflow_hub')
#       5 from tensorflow import keras   # Use this instead of tf.keras
# ----> 6 import tensorflow_hub as hub
#       8 IMAGE_SHAPE = (224, 224)
#      10 # Use the legacy keras Sequential model
#
# File ~/Desktop/data-science/venv/lib/python3.10/site-packages/tensorflow_hub/__init__.py:85
#      74   if (parse_version(tf.__version__) <
#      75       parse_version(required_tensorflow_version)):
#      76     raise ImportError(
#      77         "\n\nThis version of tensorflow_hub requires tensorflow "
#      78         "version >= {required}; Detected an installation of version {present}. "
# ...

# %%
data_dir = './datasets/flower_photos'

# %%
import os 
os.chdir('/Users/apple/Desktop/Data science/data-augmentation')

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir

# %%
list(data_dir.glob("*"))

# %%
flower_images_dict = {
    "roses":list(data_dir.glob("roses/*")),
    "daisy":list(data_dir.glob("daisy/*")),
    "dandelion":list(data_dir.glob("dandelion/*")),
    "sunflowers":list(data_dir.glob("sunflowers/*")),
    "tulips":list(data_dir.glob("sunflowers/*"))
}
flower_images_dict

# %%
flower_labels_dict = {
    "roses": 0,
    "daisy": 1,
    "dandelion": 2,
    "sunflowers": 3,
    "tulips": 4
}

# %%
import cv2
X, y = [], []
for flower_name, images in flower_images_dict.items():
    for image in images:
        try:
            img = cv2.imread(str(image))
            resized = cv2.resize(img, IMAGE_SHAPE)
            X.append(resized)
            y.append(flower_labels_dict[flower_name])
        except Exception as e:
            pass

# %%
X = np.array(X)
y = np.array(y)
X, y

# %%
X = X/255

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100, test_size=0.2)
