# %%
class MinHeap():
    def __init__(self):
        heap = []
        pass
    def __len__(self):
        pass
    def __repr__(self):
        pass
    def __insert__(self, key, value):
        pass
